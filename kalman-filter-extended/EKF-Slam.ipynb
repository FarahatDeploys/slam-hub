# %% [markdown]
# # EKF-Slam
#
# ## Introduction
#
# In this lecture we focus futher on how exactly one can develop SLAM algorithm assuming we are using the extended version of kalman filter for the prediction and update steps.
#
# in the lecture we focus on estimating the current pose of the robot not the full pose of the robot, or in other words we are interested only in the online slam problem not offline one where all the previous pose estimates is a necessaity.
#
# $$P(x_{t},m | u_{1:t-1},z_{1:t-1}) = ? $$
#
#
# ## state representation
#
# Before starting the implementation steps, we need to figure out how exactly is the state including the map and the localization of the cobot will be estimated.
#
# under the assumption that you managed to resolve the correspondance problem, in other words which feature is which right now, resulting the following state vector for the mean ($\mu$):
#
# $$x_{t} = (x,y,\theta, m_{1,x},m_{1,y},.....)$$
